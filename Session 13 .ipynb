# %%
import os
import numpy as np
import matplotlib.pyplot as plt

x = ['A','B','C']
y = [203,240,450]

plt.barh(x, y)
plt.title('`sample')
plt.xlabel('x')
plt.ylabel('y')  
for i, v in enumerate(y):
    plt.text(v +5, i , str(v))
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

x = ['A','B','C']
y = [203,240,450]

plt.bar(x, y)
plt.title('sample')
plt.xlabel('x')
plt.ylabel('y')  
for i, v in enumerate(y):
    plt.text(i-.1, v+5 , str(v))
plt.show()

# %%
x=[1,3,5,7,5]
y=[2,4,2,3,8]
plt.xlabel("X-axis")

plt.plot(x,y,"sb")
plt.xlim(-1,10)
plt.xticks((-1,0,1,3,4,5,6,7,8,9,10))
plt.grid(b=True)
for x_cor,y_cor in zip(x,y):
    plt.text(x_cor+0.1,y_cor-0.1,str((x_cor,y_cor)))
plt.show()

# %%
#Case study of module 5 

import pandas as pd

# %%
df=pd.read_csv('AllCountries.csv')

# %%
print ( list(df  [df['LandArea']>2000]['Country']) )
# Out:
# ['Algeria', 'Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'Congo, Dem. Rep.', 'India', 'Kazakhstan', 'Russian Federation', 'Saudi Arabia', 'Sudan', 'United States']

# %%
plt.scatter(df['GDP'],df['BirthRate'])
plt.xlabel('GDP')
plt.ylabel('BirthRate')
plt.title('GDP v/s BirthRate')
# Out:
# Text(0.5, 1.0, 'GDP v/s BirthRate')

# %%
top10Countries=df.sort_values('GDP',ascending=False).head(10)[['Country','GDP']]

# %%
top10Countries
# Out:
#               Country       GDP
# 113        Luxembourg  110665.0
# 143            Norway  100898.0
# 156             Qatar   93714.0
# 114  Macao SAR, China   91376.0
# 186       Switzerland   84748.0
# 10          Australia   67463.0
# 185            Sweden   60381.0
# 52            Denmark   59819.0
# 168         Singapore   55182.0
# 204     United States   53042.0

# %%
plt.barh(top10Countries['Country'],top10Countries['GDP'])
# Out:
# <BarContainer object of 10 artists>

# %%
plt.pie(top10Countries['GDP'],labels=top10Countries['Country'],autopct="%.2f")
plt.show()

# %% [markdown]
# ### ML

# %%
df=pd.read_csv('train.csv')

# %%
df['Age']=df['Age'].fillna(30)

# %%
df['Sex']=df['Sex'].map({"male":0,"female":1})

# %%
len(df)
# Out:
# 891

# %%
train=df.sample(800)

# %%
len(train)
# Out:
# 800

# %%
test=df.drop(train.index)

# %%
len(test)
# Out:
# 91

# %%
features=['Pclass','Age','Sex']
label=['Survived']

# %%
train_features=train[features]
test_features=test[features]

train_label=train[label]
test_label=test[label]

# %%
from sklearn.linear_model import LogisticRegression

# %%
l=LogisticRegression()

# %%
model=l.fit(train_features,train_label)
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/apple/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
pred=model.predict(test_features)

# %%
test_label['Prediction']=pred
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.metrics import accuracy_score

accuracy_score(test_label['Survived'],test_label['Prediction'])
# Out:
# 0.7582417582417582

# %%
#engineeryashsaxena@gmail.com
