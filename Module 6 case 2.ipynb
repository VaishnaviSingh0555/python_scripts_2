# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\vinayak.lakeshri\Documents\dataset\cereal.csv')
plt.hist(df['sugars'])
# Out:
# (array([ 8.,  4., 13.,  6.,  7.,  9.,  9.,  5., 11.,  5.]),
#  array([-1. ,  0.6,  2.2,  3.8,  5.4,  7. ,  8.6, 10.2, 11.8, 13.4, 15. ]),
#  <a list of 10 Patch objects>)

# %%
# gr=data.groupby(['name','mfr'])

# res=[]
# for key,subset in gr:
#     total_count=len(subset)
#     survived_count=subset['mfr'].sum()
#     percentage=df[['col1','col2']].map(df.set_index(['col1','col2])['col3'])
#     res.append((str(key),percentage))
#     print (key,percentage)

df['mfr'].value_counts()
gr=df.groupby('mfr')

# %%
import pandas as pd 
  
# Creating the dataframe  
df = pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\cereal.csv") 
  
# First grouping based on "Team" 
# Within each team we are grouping based on "Position" 
gkk = df.groupby(['mfr', 'name']) 
gkk.first()
# Out:
#                                       type  calories  protein  fat  sodium  \
# mfr name
# A   Maypo                                H       100        4    1       0
# G   Apple Cinnamon Cheerios              C       110        2    2     180
#     Basic 4                              C       130        3    2     210
#     Cheerios                             C       110        6    2     290
#     Cinnamon Toast Crunch                C       120        1    3     210
# ...                                    ...       ...      ...  ...     ...
# R   Double Chex                          C       100        2    0     190
#     Muesli Raisins; Dates; & Almonds     C       150        4    3      95
#     Muesli Raisins; Peaches; & Pecans    C       150        4    3     150
#     Rice Chex                            C       110        1    0     240
#     Wheat Chex                           C       100        3    1     230
#
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\cereal.csv")
data.head()
y=data.mfr
x=data.drop('mfr',axis=1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.head()
# Out:
#                   name type  calories  protein  fat  sodium  fiber  carbo  \
# 50   Nutri-grain Wheat    C        90        3    0     170    3.0   18.0
# 54         Puffed Rice    C        50        1    0       0    0.0   13.0
# 18       Count Chocula    C       110        1    1     180    0.0   12.0
# 19  Cracklin' Oat Bran    C       110        3    3     140    4.0   10.0
# 53          Product 19    C       100        3    0     320    1.0   20.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 50       2      90        25      3     1.0   1.0  59.642837
# 54       0      15         0      3     0.5   1.0  60.756112
# 18      13      65        25      2     1.0   1.0  22.396513
# 19       7     160        25      3     1.0   0.5  40.448772
# 53       3      45       100      3     1.0   1.0  41.503540

# %%
seed=1234
import pandas as pd
data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\cereal.csv")

features=['name','mfr','type','calories']
target=['rating']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['shelf'])
coeff_df

y_pred = regressor.predict(X_test)

df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df

from sklearn import metrics

print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-e6b860e96f9a> in <module>
#      11 from sklearn.linear_model import LinearRegression
#      12 regressor = LinearRegression()
# ---> 13 regressor.fit(X_train, y_train)
#      14
#      15 # coeff_df = pd.DataFrame(regressor.coef_, X.columns, columns=['shelf'])
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dataset = pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\cereal.csv")

X = dataset[['name','mfr','type','calories'
       ]]
y = dataset['Petrol_Consumption']

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
