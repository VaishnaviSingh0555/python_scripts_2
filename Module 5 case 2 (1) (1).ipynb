# %%
import pandas as pd
data = pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")

df=pd.DataFrame()

print(df)

mean_year = data.groupby('Year').mean()['TotalPay']

print ( mean_year)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
# Year
# 2011    71743.819645
# 2012    74112.234931
# 2013    77611.443142
# 2014    75471.836912
# Name: TotalPay, dtype: float64
# C:\Users\vinayak.lakeshri\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import pandas as pd

# import matplotlib.pyplot as plt

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")

df=pd.DataFrame(data)

print(df)
data.info()
mean_salary = data.loc[data['TotalPayBenefits'].idxmin()]

print ( mean_salary)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148643                       Human Services Technician       0.00
# ...

# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")
df=pd.DataFrame(data)
df[df.Year== 2014].groupby(["JobTitle"]).mean().head()
# Out:
#                                          Id       BasePay  OvertimePay  \
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)   135284.000000  62290.780000     0.000000
# ASR Senior Office Specialist  132123.409091  57989.199545   464.468182
# ASR-Office Assistant          136803.733333  44470.024667     0.000000
# Account Clerk                 138191.344086  37050.567312    89.327312
# Accountant I                  135276.500000  45404.635000     0.000000
#
#                                  OtherPay      Benefits      TotalPay  \
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)      0.000000  17975.590000  62290.780000
# ASR Senior Office Specialist  3932.986364  25136.138636  62386.654091
# ASR-Office Assistant           217.771333  22129.500000  44687.796000
# Account Clerk                  541.338602  17541.932903  37681.233226
# Accountant I                     0.000000  18773.695000  45404.635000
#
#                               TotalPayBenefits    Year  Notes
# JobTitle
# ...

# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")
df=pd.DataFrame(data)
df['Saved_money'] = df['TotalPay'] - df['OvertimePay'] 
print("\nThe saved amount is :\n", df)
# Out:
# The saved amount is :
#              Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148643  148646   Carolyn A Wilson
# 148644  148648     Joann Anderson
# 148645  148649        Leon Walker
# 148646  148650      Roy I Tillery
# 148647  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")
df=pd.DataFrame(data)
df[df.Year== 2014].groupby(["JobTitle"]).mean().head()
# Out:
#                                          Id       BasePay  OvertimePay  \
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)   135284.000000  62290.780000     0.000000
# ASR Senior Office Specialist  132123.409091  57989.199545   464.468182
# ASR-Office Assistant          136803.733333  44470.024667     0.000000
# Account Clerk                 138191.344086  37050.567312    89.327312
# Accountant I                  135276.500000  45404.635000     0.000000
#
#                                  OtherPay      Benefits      TotalPay  \
# JobTitle
# ACPO,JuvP, Juv Prob (SFERS)      0.000000  17975.590000  62290.780000
# ASR Senior Office Specialist  3932.986364  25136.138636  62386.654091
# ASR-Office Assistant           217.771333  22129.500000  44687.796000
# Account Clerk                  541.338602  17541.932903  37681.233226
# Accountant I                     0.000000  18773.695000  45404.635000
#
#                               TotalPayBenefits    Year  Notes
# JobTitle
# ...

# %%
import pandas as pd

data=pd.read_csv(r"C:\Users\vinayak.lakeshri\Documents\dataset\Salaries.csv")
df=pd.DataFrame(data)
highest_paid = df.loc[df['TotalPayBenefits'].idxmax()]
highest_paid['EmployeeName']
# Out:
# 'NATHANIEL FORD'
